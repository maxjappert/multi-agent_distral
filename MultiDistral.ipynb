# %% [markdown]
# # V1.0

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from gridworld_env import GridworldEnv
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from algorithms.MultiDistral.MultiDistral import MultiDistral

def updatefig(j):
    # set the data in the axesimage object~
    im.set_array(env.grid_images[j])
    # return the artists set
    return [im]

# %% [markdown]
# #### WITH TASK 4

# %%
from algorithms.MultiDistral.MultiDistral_E_step.Soft_Q_Learning_without_rollout import Soft_without_rollout
# Q learning params
ALPHA = 0.1 # learning rate
GAMMA = 0.99 # reward discount
BETA=0.5
TEST_COUNT = 100

TURN_LIMIT = 1000
v1=MultiDistral( TURN_LIMIT, ALPHA, GAMMA, BETA,Soft_without_rollout)

v1.optimise(2)
plt.xlabel('MultiDistral Iteration')
plt.ylabel('Average return per game')
plt.legend(['Player 1', 'Player 2'])
plt.title('Learning curves of both agents for V2 of MultiDistral')
plt.savefig("V2_task4.pdf", format="pdf", bbox_inches="tight")
# Out:
# /Users/samueloliveira/opt/anaconda3/envs/maai-env/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10

# %%
from algorithms.MultiDistral.MultiDistral_E_step.Soft_Q_Learning_without_rollout import Soft_without_rollout
# Q learning params
ALPHA = 0.1 # learning rate
GAMMA = 0.99 # reward discount
BETA=0.5
TEST_COUNT = 100

TURN_LIMIT = 200
v1=MultiDistral( TURN_LIMIT, ALPHA, GAMMA,BETA,Soft_without_rollout)

v1.optimise(1)
plt.xlabel('MultiDistral Iteration')
plt.ylabel('Average return per game')
plt.legend(['Player 1', 'Player 2'])
plt.title('Learning curves of both agents for V1 of MultiDistral')
plt.savefig("V1_task4.pdf", format="pdf", bbox_inches="tight")
# Out:
# /Users/samueloliveira/opt/anaconda3/envs/maai-env/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10

# %%
from algorithms.MultiDistral.MultiDistral_E_step.Soft_Q_Learning_without_rollout import Soft_without_rollout
# Q learning params
ALPHA = 0.1 # learning rate
GAMMA = 0.99 # reward discount
BETA=0.5
TEST_COUNT = 100

TURN_LIMIT = 500
v1=MultiDistral( TURN_LIMIT, ALPHA, GAMMA, BETA,Soft_without_rollout)

v1.optimise(1)
plt.xlabel('MultiDistral Iteration')
plt.ylabel('Average return per game')
plt.legend(['Player 1', 'Player 2'])
plt.title('Learning curves of both agents for V1 of MultiDistral')
plt.savefig("V1_3.pdf", format="pdf", bbox_inches="tight")
# Out:
# /Users/samueloliveira/opt/anaconda3/envs/maai-env/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
# Iteration 15
# Iteration 16
# Iteration 17
# Iteration 18
# Iteration 19
# Iteration 20

# %% [markdown]
# #### WITHOUT TASK 4

# %%
from algorithms.MultiDistral.MultiDistral_E_step.Soft_Q_Learning_without_rollout import Soft_without_rollout
# Q learning params
ALPHA = 0.1 # learning rate
GAMMA = 0.99 # reward discount
BETA=0.5
TEST_COUNT = 100

TURN_LIMIT = 200
v1=MultiDistral(TURN_LIMIT, ALPHA, GAMMA, BETA,Soft_without_rollout)

v1.optimise(1)
plt.xlabel('MultiDistral Iteration')
plt.ylabel('Average return per game')
plt.legend(['Player 1', 'Player 2'])
plt.title('Learning curves of both agents for V2 of MultiDistral')
plt.savefig("V1_without_task4.pdf", format="pdf", bbox_inches="tight")
# Out:
# /Users/samueloliveira/opt/anaconda3/envs/maai-env/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10

# %%
from algorithms.MultiDistral.MultiDistral_E_step.Soft_Q_Learning_without_rollout import Soft_without_rollout
# Q learning params
ALPHA = 0.1 # learning rate
GAMMA = 0.99 # reward discount
BETA=0.5
TEST_COUNT = 100

TURN_LIMIT = 200
v1=MultiDistral(TURN_LIMIT, ALPHA, GAMMA, BETA,Soft_without_rollout)

v1.optimise(2)
plt.xlabel('MultiDistral Iteration')
plt.ylabel('Average return per game')
plt.legend(['Player 1', 'Player 2'])
plt.title('Learning curves of both agents for V2 of MultiDistral')
plt.savefig("V2_without_task4.pdf", format="pdf", bbox_inches="tight")
# Out:
# /Users/samueloliveira/opt/anaconda3/envs/maai-env/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10

# %% [markdown]
# ### REPETITIONS TO GET BETTER RESULTS

# %% [markdown]
# #### WITH TASK 4

# %%
from algorithms.MultiDistral.MultiDistral_E_step.Soft_Q_Learning_without_rollout import Soft_without_rollout
# Q learning params
ALPHA = 0.1 # learning rate
GAMMA = 0.99 # reward discount
BETA=0.5
TEST_COUNT = 100

TURN_LIMIT = 1000
v1=MultiDistral( TURN_LIMIT, ALPHA, GAMMA, BETA,Soft_without_rollout)

v1.optimise(1)
plt.xlabel('MultiDistral Iteration')
plt.ylabel('Average return per game')
plt.legend(['Player 1', 'Player 2'])
plt.title('Learning curves of both agents for V1 of MultiDistral')
plt.savefig("V1_task4_try2.pdf", format="pdf", bbox_inches="tight")
# Out:
# /Users/samueloliveira/opt/anaconda3/envs/maai-env/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10

# %%
from algorithms.MultiDistral.MultiDistral_E_step.Soft_Q_Learning_without_rollout import Soft_without_rollout
# Q learning params
ALPHA = 0.1 # learning rate
GAMMA = 0.99 # reward discount
BETA=0.5
TEST_COUNT = 100

TURN_LIMIT = 1000
v1=MultiDistral( TURN_LIMIT, ALPHA, GAMMA, BETA,Soft_without_rollout)

v1.optimise(2)
plt.xlabel('MultiDistral Iteration')
plt.ylabel('Average return per game')
plt.legend(['Player 1', 'Player 2'])
plt.title('Learning curves of both agents for V2 of MultiDistral')
plt.savefig("V2_task4_try2.pdf", format="pdf", bbox_inches="tight")
# Out:
# /Users/samueloliveira/opt/anaconda3/envs/maai-env/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10

# %% [markdown]
# #### WITHOUT TASK 4

# %%
from algorithms.MultiDistral.MultiDistral_E_step.Soft_Q_Learning_without_rollout import Soft_without_rollout
# Q learning params
ALPHA = 0.1 # learning rate
GAMMA = 0.99 # reward discount
BETA=0.5
TEST_COUNT = 100

TURN_LIMIT = 1000
v1=MultiDistral( TURN_LIMIT, ALPHA, GAMMA, BETA,Soft_without_rollout)

v1.optimise(1)
plt.xlabel('MultiDistral Iteration')
plt.ylabel('Average return per game')
plt.legend(['Player 1', 'Player 2'])
plt.title('Learning curves of both agents for V1 of MultiDistral')
plt.savefig("V1_without_task4_try2.pdf", format="pdf", bbox_inches="tight")
# Out:
# /Users/samueloliveira/opt/anaconda3/envs/maai-env/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10

# %%
from algorithms.MultiDistral.MultiDistral_E_step.Soft_Q_Learning_without_rollout import Soft_without_rollout
# Q learning params
ALPHA = 0.1 # learning rate
GAMMA = 0.99 # reward discount
BETA=0.5
TEST_COUNT = 100

TURN_LIMIT = 1000
v1=MultiDistral( TURN_LIMIT, ALPHA, GAMMA, BETA,Soft_without_rollout)

v1.optimise(2)
plt.xlabel('MultiDistral Iteration')
plt.ylabel('Average return per game')
plt.legend(['Player 1', 'Player 2'])
plt.title('Learning curves of both agents for V2 of MultiDistral')
plt.savefig("V2_without_task4_try2.pdf", format="pdf", bbox_inches="tight")
# Out:
# /Users/samueloliveira/opt/anaconda3/envs/maai-env/lib/python3.12/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
